# %%
import pandas as pd
df = pd.read_pickle("../data/df_100k.pkl")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   rating             100000 non-null  int64
#  1   title              100000 non-null  object
#  2   text               100000 non-null  object
#  3   images             100000 non-null  object
#  4   asin               100000 non-null  object
#  5   parent_asin        100000 non-null  object
#  6   user_id            100000 non-null  object
#  7   timestamp          100000 non-null  datetime64[ns]
#  8   helpful_vote       100000 non-null  int64
#  9   verified_purchase  100000 non-null  bool
# dtypes: bool(1), datetime64[ns](1), int64(2), object(6)
# memory usage: 7.0+ MB

# %%
import sys
sys.path.append("../src")

from preprocess import preprocess_pipeline, save_serialized

train, test, df_model, user_enc, item_enc = preprocess_pipeline(df)

# %%
save_serialized(train, test, df_model)
print("train.pkl, test.pkl, df_model.pkl guardados.")
# Out:
# train.pkl, test.pkl, df_model.pkl guardados.
